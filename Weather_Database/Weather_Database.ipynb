# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

#lat_lngs

# %%
coordinates = list(lat_lngs)
# coordinates

# %%
cities = []

# nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 755

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") # This will find the corresponding weather data

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    

    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | awjilah
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | deniliquin
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | huanren
# Processing Record 8 of Set 1 | jumla
# Processing Record 9 of Set 1 | emerald
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | ketchikan
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | clyde river
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | aklavik
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | wanning
# Processing Record 28 of Set 1 | buchanan
# Processing Record 29 of Set 1 | souillac
# Processing Record 30 of Set 1 | iqaluit
# Processing Record 31 of Set 1 | eirunepe
# Processing Record 32 of Set 1 | dutlwe
# Processing Record 33 of Set 1 | namatanai
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | tselinnoye
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | sorland
# Processing Record 40 of Set 1 | banska stiavnica
# Processing Record 41 of Set 1 | neuquen
# Processing Record 42 of Set 1 | kaeo
# Processing Record 43 of Set 1 | perez
# Processing Record 44 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 1 | eskilstuna
# Processing Record 46 of Set 1 | cartagena
# Processing Record 47 of Set 1 | loandjili
# Processing Record 48 of Set 1 | santa rosa
# Processing Record 49 of Set 1 | buala
# Processing Record 50 of Set 1 | auki
# Processing Record 1 of Set 2 | kyra
# Processing Record 2 of Set 2 | nuevo ideal
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | concordia
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | la orilla
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | cabo san lucas
# Processing Record 9 of Set 2 | chicama
# Processing Record 10 of Set 2 | prokopyevsk
# Processing Record 11 of Set 2 | haines junction
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | grand-santi
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | qandala
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | sault sainte marie
# Processing Record 23 of Set 2 | nanortalik
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | grandview
# Processing Record 26 of Set 2 | clinton
# Processing Record 27 of Set 2 | muravlenko
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | sterling
# Processing Record 30 of Set 2 | mayo
# Processing Record 31 of Set 2 | jinchang
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | floro
# Processing Record 34 of Set 2 | mandera
# Processing Record 35 of Set 2 | almenevo
# City not found. Skipping...
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | taunggyi
# Processing Record 39 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 2 | tura
# Processing Record 41 of Set 2 | poso
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | port hedland
# Processing Record 44 of Set 2 | maniitsoq
# Processing Record 45 of Set 2 | itarema
# Processing Record 46 of Set 2 | port augusta
# Processing Record 47 of Set 2 | faanui
# Processing Record 48 of Set 2 | teya
# Processing Record 49 of Set 2 | colares
# Processing Record 50 of Set 2 | taoudenni
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | isangel
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | princeton
# Processing Record 5 of Set 3 | linfen
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | iskateley
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | codrington
# Processing Record 11 of Set 3 | rosetta
# Processing Record 12 of Set 3 | guerrero negro
# Processing Record 13 of Set 3 | port blair
# Processing Record 14 of Set 3 | bouca
# Processing Record 15 of Set 3 | bettiah
# Processing Record 16 of Set 3 | nouadhibou
# Processing Record 17 of Set 3 | murdochville
# Processing Record 18 of Set 3 | cherskiy
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | havoysund
# Processing Record 21 of Set 3 | xadani
# City not found. Skipping...
# Processing Record 22 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | glens falls
# Processing Record 26 of Set 3 | isabela
# Processing Record 27 of Set 3 | weyburn
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | talnakh
# Processing Record 31 of Set 3 | ratnagiri
# Processing Record 32 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | esfarayen
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | misratah
# Processing Record 37 of Set 3 | saskylakh
# Processing Record 38 of Set 3 | yellowknife
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | port moresby
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | alenquer
# Processing Record 44 of Set 3 | mananjary
# Processing Record 45 of Set 3 | bataipora
# Processing Record 46 of Set 3 | ngunguru
# Processing Record 47 of Set 3 | stavern
# Processing Record 48 of Set 3 | aragarcas
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 50 of Set 3 | lerwick
# Processing Record 1 of Set 4 | dera din panah
# City not found. Skipping...
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | kiunga
# Processing Record 5 of Set 4 | alyangula
# Processing Record 6 of Set 4 | egvekinot
# Processing Record 7 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 9 of Set 4 | ust-kuyga
# Processing Record 10 of Set 4 | barrow
# Processing Record 11 of Set 4 | vaini
# Processing Record 12 of Set 4 | dikson
# Processing Record 13 of Set 4 | mazatlan
# Processing Record 14 of Set 4 | cockburn town
# Processing Record 15 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 4 | santa maria
# Processing Record 17 of Set 4 | pevek
# Processing Record 18 of Set 4 | puerto ayora
# Processing Record 19 of Set 4 | kruisfontein
# Processing Record 20 of Set 4 | veles
# Processing Record 21 of Set 4 | nemuro
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | belmonte
# Processing Record 25 of Set 4 | elizabeth city
# Processing Record 26 of Set 4 | towada
# Processing Record 27 of Set 4 | tiksi
# Processing Record 28 of Set 4 | smolensk
# Processing Record 29 of Set 4 | catuday
# Processing Record 30 of Set 4 | salinopolis
# Processing Record 31 of Set 4 | el faiyum
# City not found. Skipping...
# Processing Record 32 of Set 4 | grindavik
# Processing Record 33 of Set 4 | mbini
# Processing Record 34 of Set 4 | zyryanka
# Processing Record 35 of Set 4 | eureka
# Processing Record 36 of Set 4 | banes
# Processing Record 37 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 4 | jinxiang
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | los llanos de aridane
# Processing Record 42 of Set 4 | coquimbo
# Processing Record 43 of Set 4 | litayen
# City not found. Skipping...
# Processing Record 44 of Set 4 | waingapu
# Processing Record 45 of Set 4 | aykhal
# Processing Record 46 of Set 4 | cusuna
# Processing Record 47 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 4 | okitipupa
# Processing Record 49 of Set 4 | calamar
# Processing Record 50 of Set 4 | lebu
# Processing Record 1 of Set 5 | bonavista
# Processing Record 2 of Set 5 | portland
# Processing Record 3 of Set 5 | kahului
# Processing Record 4 of Set 5 | vao
# Processing Record 5 of Set 5 | cayenne
# Processing Record 6 of Set 5 | sola
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | sundumbili
# Processing Record 10 of Set 5 | minuri
# Processing Record 11 of Set 5 | mayya
# Processing Record 12 of Set 5 | manicore
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | otjimbingwe
# Processing Record 15 of Set 5 | jardim
# Processing Record 16 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 5 | matagami
# Processing Record 18 of Set 5 | nabinagar
# Processing Record 19 of Set 5 | toyooka
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | kloulklubed
# Processing Record 22 of Set 5 | riyadh
# Processing Record 23 of Set 5 | emba
# Processing Record 24 of Set 5 | huetamo
# City not found. Skipping...
# Processing Record 25 of Set 5 | naze
# Processing Record 26 of Set 5 | chimbote
# Processing Record 27 of Set 5 | port macquarie
# Processing Record 28 of Set 5 | hobyo
# Processing Record 29 of Set 5 | zalantun
# Processing Record 30 of Set 5 | cap malheureux
# Processing Record 31 of Set 5 | poli
# Processing Record 32 of Set 5 | ahipara
# Processing Record 33 of Set 5 | roma
# Processing Record 34 of Set 5 | wad rawah
# Processing Record 35 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 5 | ermelo
# Processing Record 37 of Set 5 | imbituba
# Processing Record 38 of Set 5 | acajutla
# Processing Record 39 of Set 5 | vestmanna
# Processing Record 40 of Set 5 | alice springs
# Processing Record 41 of Set 5 | constitucion
# Processing Record 42 of Set 5 | gari
# Processing Record 43 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 5 | kavieng
# Processing Record 45 of Set 5 | salinas
# Processing Record 46 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 5 | praia da vitoria
# Processing Record 48 of Set 5 | kosh-agach
# Processing Record 49 of Set 5 | marzuq
# Processing Record 50 of Set 5 | oktyabrskoye
# Processing Record 1 of Set 6 | tukrah
# Processing Record 2 of Set 6 | puri
# Processing Record 3 of Set 6 | fortuna
# Processing Record 4 of Set 6 | upington
# Processing Record 5 of Set 6 | sao joao da barra
# Processing Record 6 of Set 6 | bismarck
# Processing Record 7 of Set 6 | ugoofaaru
# Processing Record 8 of Set 6 | shunyi
# Processing Record 9 of Set 6 | kenora
# Processing Record 10 of Set 6 | markova
# Processing Record 11 of Set 6 | ode
# Processing Record 12 of Set 6 | puerto maldonado
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | ca mau
# Processing Record 15 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 6 | richards bay
# Processing Record 17 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 6 | curvelo
# Processing Record 19 of Set 6 | grimmen
# Processing Record 20 of Set 6 | tual
# Processing Record 21 of Set 6 | acarau
# Processing Record 22 of Set 6 | daru
# Processing Record 23 of Set 6 | rawson
# Processing Record 24 of Set 6 | lavrentiya
# Processing Record 25 of Set 6 | zhezkazgan
# Processing Record 26 of Set 6 | safaqis
# City not found. Skipping...
# Processing Record 27 of Set 6 | macamic
# Processing Record 28 of Set 6 | rocha
# Processing Record 29 of Set 6 | saint george
# Processing Record 30 of Set 6 | grand gaube
# Processing Record 31 of Set 6 | pacific grove
# Processing Record 32 of Set 6 | fougamou
# Processing Record 33 of Set 6 | opuwo
# Processing Record 34 of Set 6 | xining
# Processing Record 35 of Set 6 | carutapera
# Processing Record 36 of Set 6 | porangatu
# Processing Record 37 of Set 6 | caravelas
# Processing Record 38 of Set 6 | aksarka
# Processing Record 39 of Set 6 | faya
# Processing Record 40 of Set 6 | shimoda
# Processing Record 41 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 6 | alekseyevsk
# Processing Record 43 of Set 6 | omboue
# Processing Record 44 of Set 6 | mount isa
# Processing Record 45 of Set 6 | muros
# Processing Record 46 of Set 6 | sur
# Processing Record 47 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 48 of Set 6 | berlevag
# Processing Record 49 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 50 of Set 6 | rio gallegos
# Processing Record 1 of Set 7 | quelimane
# Processing Record 2 of Set 7 | saint-leu
# Processing Record 3 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 7 | college
# Processing Record 5 of Set 7 | bengkulu
# Processing Record 6 of Set 7 | luanda
# Processing Record 7 of Set 7 | shirokiy
# Processing Record 8 of Set 7 | severo-kurilsk
# Processing Record 9 of Set 7 | san cristobal
# Processing Record 10 of Set 7 | kangaatsiaq
# Processing Record 11 of Set 7 | tuatapere
# Processing Record 12 of Set 7 | amahai
# Processing Record 13 of Set 7 | ligayan
# Processing Record 14 of Set 7 | vanimo
# Processing Record 15 of Set 7 | baherden
# Processing Record 16 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 7 | socorro
# Processing Record 18 of Set 7 | nicoya
# Processing Record 19 of Set 7 | santa fe
# Processing Record 20 of Set 7 | norman wells
# Processing Record 21 of Set 7 | dovers
# Processing Record 22 of Set 7 | ambulu
# Processing Record 23 of Set 7 | nome
# Processing Record 24 of Set 7 | moshenskoye
# Processing Record 25 of Set 7 | mobaye
# Processing Record 26 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 7 | ilulissat
# Processing Record 28 of Set 7 | rundu
# Processing Record 29 of Set 7 | benguela
# Processing Record 30 of Set 7 | gadu
# Processing Record 31 of Set 7 | ajaccio
# Processing Record 32 of Set 7 | snyder
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | dryden
# Processing Record 35 of Set 7 | karangasem
# Processing Record 36 of Set 7 | san luis
# Processing Record 37 of Set 7 | bathsheba
# Processing Record 38 of Set 7 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 39 of Set 7 | te anau
# Processing Record 40 of Set 7 | kavaratti
# Processing Record 41 of Set 7 | bowen
# Processing Record 42 of Set 7 | sept-iles
# Processing Record 43 of Set 7 | rexburg
# Processing Record 44 of Set 7 | zhangye
# Processing Record 45 of Set 7 | vaitape
# Processing Record 46 of Set 7 | olafsvik
# Processing Record 47 of Set 7 | saint-augustin
# Processing Record 48 of Set 7 | labuhan
# Processing Record 49 of Set 7 | dingle
# Processing Record 50 of Set 7 | tilichiki
# Processing Record 1 of Set 8 | malatya
# Processing Record 2 of Set 8 | larsnes
# Processing Record 3 of Set 8 | chernyshevskiy
# Processing Record 4 of Set 8 | yako
# Processing Record 5 of Set 8 | west wendover
# Processing Record 6 of Set 8 | yuncheng
# Processing Record 7 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 8 | izumo
# Processing Record 10 of Set 8 | zilair
# Processing Record 11 of Set 8 | asosa
# Processing Record 12 of Set 8 | gallup
# Processing Record 13 of Set 8 | kamaishi
# Processing Record 14 of Set 8 | fernandopolis
# Processing Record 15 of Set 8 | pozo colorado
# Processing Record 16 of Set 8 | vestmannaeyjar
# Processing Record 17 of Set 8 | luderitz
# Processing Record 18 of Set 8 | ndiekro
# City not found. Skipping...
# Processing Record 19 of Set 8 | oyama
# Processing Record 20 of Set 8 | hay river
# Processing Record 21 of Set 8 | shelburne
# Processing Record 22 of Set 8 | muisne
# Processing Record 23 of Set 8 | arcata
# Processing Record 24 of Set 8 | airai
# Processing Record 25 of Set 8 | klaksvik
# Processing Record 26 of Set 8 | schaffhausen
# Processing Record 27 of Set 8 | nantucket
# Processing Record 28 of Set 8 | yaring
# Processing Record 29 of Set 8 | pisco
# Processing Record 30 of Set 8 | billings
# Processing Record 31 of Set 8 | lorengau
# Processing Record 32 of Set 8 | umea
# Processing Record 33 of Set 8 | alugan
# Processing Record 34 of Set 8 | narrabri
# Processing Record 35 of Set 8 | kutum
# Processing Record 36 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 8 | kendallville
# Processing Record 38 of Set 8 | wum
# Processing Record 39 of Set 8 | srednekolymsk
# Processing Record 40 of Set 8 | deputatskiy
# Processing Record 41 of Set 8 | hammerfest
# Processing Record 42 of Set 8 | bonnyville
# Processing Record 43 of Set 8 | chokurdakh
# Processing Record 44 of Set 8 | fuxin
# Processing Record 45 of Set 8 | sabang
# Processing Record 46 of Set 8 | sitka
# Processing Record 47 of Set 8 | carnarvon
# Processing Record 48 of Set 8 | ishigaki
# Processing Record 49 of Set 8 | lewisville
# Processing Record 50 of Set 8 | kiama
# Processing Record 1 of Set 9 | komsomolskiy
# Processing Record 2 of Set 9 | esperance
# Processing Record 3 of Set 9 | antalaha
# Processing Record 4 of Set 9 | yamada
# Processing Record 5 of Set 9 | salalah
# Processing Record 6 of Set 9 | santarem
# Processing Record 7 of Set 9 | ixtapa
# Processing Record 8 of Set 9 | hofn
# Processing Record 9 of Set 9 | san patricio
# Processing Record 10 of Set 9 | cedar city
# Processing Record 11 of Set 9 | yar-sale
# Processing Record 12 of Set 9 | obigarm
# Processing Record 13 of Set 9 | chaman
# Processing Record 14 of Set 9 | seoul
# Processing Record 15 of Set 9 | limpapa
# Processing Record 16 of Set 9 | natitingou
# Processing Record 17 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 9 | hlotse
# Processing Record 19 of Set 9 | manokwari
# Processing Record 20 of Set 9 | ulagan
# Processing Record 21 of Set 9 | lasa
# Processing Record 22 of Set 9 | vostok
# Processing Record 23 of Set 9 | korla
# Processing Record 24 of Set 9 | kvareli
# Processing Record 25 of Set 9 | aguas vermelhas
# Processing Record 26 of Set 9 | zhigalovo
# Processing Record 27 of Set 9 | darhan
# Processing Record 28 of Set 9 | termiz
# Processing Record 29 of Set 9 | skelleftea
# Processing Record 30 of Set 9 | gombong
# Processing Record 31 of Set 9 | gujar khan
# Processing Record 32 of Set 9 | puerto leguizamo
# Processing Record 33 of Set 9 | callaguip
# Processing Record 34 of Set 9 | verkhoyansk
# Processing Record 35 of Set 9 | champerico
# Processing Record 36 of Set 9 | vila franca do campo
# Processing Record 37 of Set 9 | nalut
# Processing Record 38 of Set 9 | gloucester
# Processing Record 39 of Set 9 | tezu
# Processing Record 40 of Set 9 | volkhov
# Processing Record 41 of Set 9 | laranjeiras do sul
# Processing Record 42 of Set 9 | ancud
# Processing Record 43 of Set 9 | marquette
# Processing Record 44 of Set 9 | palmer
# Processing Record 45 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 46 of Set 9 | svetlyy
# Processing Record 47 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 48 of Set 9 | ayan
# Processing Record 49 of Set 9 | mao
# Processing Record 50 of Set 9 | tucuman
# Processing Record 1 of Set 10 | porto novo
# Processing Record 2 of Set 10 | kota belud
# Processing Record 3 of Set 10 | karatuzskoye
# Processing Record 4 of Set 10 | ede
# Processing Record 5 of Set 10 | chapais
# Processing Record 6 of Set 10 | yuzhno-kurilsk
# Processing Record 7 of Set 10 | pemangkat
# Processing Record 8 of Set 10 | aguimes
# Processing Record 9 of Set 10 | kirkland lake
# Processing Record 10 of Set 10 | araouane
# Processing Record 11 of Set 10 | quatre cocos
# Processing Record 12 of Set 10 | moussoro
# Processing Record 13 of Set 10 | harper
# Processing Record 14 of Set 10 | kelso
# Processing Record 15 of Set 10 | antofagasta
# Processing Record 16 of Set 10 | sorong
# Processing Record 17 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 18 of Set 10 | iralaya
# Processing Record 19 of Set 10 | comarapa
# Processing Record 20 of Set 10 | saint-pierre
# Processing Record 21 of Set 10 | tubmanburg
# Processing Record 22 of Set 10 | penarroya-pueblonuevo
# Processing Record 23 of Set 10 | christchurch
# Processing Record 24 of Set 10 | tanda
# Processing Record 25 of Set 10 | den helder
# Processing Record 26 of Set 10 | santa marta
# Processing Record 27 of Set 10 | eyl
# Processing Record 28 of Set 10 | turukhansk
# Processing Record 29 of Set 10 | sembe
# Processing Record 30 of Set 10 | necochea
# Processing Record 31 of Set 10 | shingu
# Processing Record 32 of Set 10 | biak
# Processing Record 33 of Set 10 | alofi
# Processing Record 34 of Set 10 | worland
# Processing Record 35 of Set 10 | bayan
# Processing Record 36 of Set 10 | bandarbeyla
# Processing Record 37 of Set 10 | merauke
# Processing Record 38 of Set 10 | mantua
# Processing Record 39 of Set 10 | impfondo
# Processing Record 40 of Set 10 | namibe
# Processing Record 41 of Set 10 | mozarlandia
# Processing Record 42 of Set 10 | kovur
# Processing Record 43 of Set 10 | atbasar
# Processing Record 44 of Set 10 | xingcheng
# Processing Record 45 of Set 10 | oudtshoorn
# Processing Record 46 of Set 10 | dongsheng
# Processing Record 47 of Set 10 | mutis
# Processing Record 48 of Set 10 | san matias
# Processing Record 49 of Set 10 | rehoboth
# Processing Record 50 of Set 10 | nybro
# Processing Record 1 of Set 11 | roswell
# Processing Record 2 of Set 11 | solnechnyy
# Processing Record 3 of Set 11 | avila
# Processing Record 4 of Set 11 | newport
# Processing Record 5 of Set 11 | ambon
# Processing Record 6 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 7 of Set 11 | danilov
# Processing Record 8 of Set 11 | adeje
# Processing Record 9 of Set 11 | terrace bay
# Processing Record 10 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 11 of Set 11 | kenai
# Processing Record 12 of Set 11 | arman
# Processing Record 13 of Set 11 | bara
# Processing Record 14 of Set 11 | bethanien
# Processing Record 15 of Set 11 | oshnaviyeh
# Processing Record 16 of Set 11 | urusha
# Processing Record 17 of Set 11 | sulangan
# Processing Record 18 of Set 11 | avera
# Processing Record 19 of Set 11 | manggar
# Processing Record 20 of Set 11 | rodrigues alves
# Processing Record 21 of Set 11 | kisaran
# Processing Record 22 of Set 11 | bilibino
# Processing Record 23 of Set 11 | ulladulla
# Processing Record 24 of Set 11 | padang
# Processing Record 25 of Set 11 | inongo
# Processing Record 26 of Set 11 | lantawan
# Processing Record 27 of Set 11 | baykit
# Processing Record 28 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 11 | rafai
# Processing Record 30 of Set 11 | iranshahr
# Processing Record 31 of Set 11 | pilar
# Processing Record 32 of Set 11 | iwanai
# Processing Record 33 of Set 11 | karratha
# Processing Record 34 of Set 11 | henties bay
# Processing Record 35 of Set 11 | wanganui
# Processing Record 36 of Set 11 | cozumel
# Processing Record 37 of Set 11 | mogapi
# Processing Record 38 of Set 11 | walvis bay
# Processing Record 39 of Set 11 | arieseni
# Processing Record 40 of Set 11 | pangnirtung
# Processing Record 41 of Set 11 | teknaf
# Processing Record 42 of Set 11 | mandalgovi
# Processing Record 43 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 11 | port hardy
# Processing Record 45 of Set 11 | heihe
# Processing Record 46 of Set 11 | half moon bay
# Processing Record 47 of Set 11 | mangrol
# Processing Record 48 of Set 11 | kalmunai
# Processing Record 49 of Set 11 | veraval
# Processing Record 50 of Set 11 | sanmenxia
# Processing Record 1 of Set 12 | nabire
# Processing Record 2 of Set 12 | westport
# Processing Record 3 of Set 12 | nioro
# Processing Record 4 of Set 12 | la paz
# Processing Record 5 of Set 12 | hami
# Processing Record 6 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 12 | ostrovnoy
# Processing Record 8 of Set 12 | haicheng
# Processing Record 9 of Set 12 | lagunas
# Processing Record 10 of Set 12 | znamenskoye
# Processing Record 11 of Set 12 | pasighat
# Processing Record 12 of Set 12 | kudahuvadhoo
# Processing Record 13 of Set 12 | moranbah
# Processing Record 14 of Set 12 | sibolga
# Processing Record 15 of Set 12 | lata
# Processing Record 16 of Set 12 | lubumbashi
# Processing Record 17 of Set 12 | coihaique
# Processing Record 18 of Set 12 | roebourne
# Processing Record 19 of Set 12 | mokokchung
# Processing Record 20 of Set 12 | umuahia
# Processing Record 21 of Set 12 | lichinga
# Processing Record 22 of Set 12 | huarmey
# Processing Record 23 of Set 12 | zhuhai
# Processing Record 24 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 25 of Set 12 | marienburg
# Processing Record 26 of Set 12 | ekibastuz
# Processing Record 27 of Set 12 | stephenville
# Processing Record 28 of Set 12 | sujiatun
# Processing Record 29 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 12 | severo-yeniseyskiy
# Processing Record 31 of Set 12 | riberalta
# Processing Record 32 of Set 12 | kunyang
# Processing Record 33 of Set 12 | tres marias
# Processing Record 34 of Set 12 | arlit
# Processing Record 35 of Set 12 | hamilton
# Processing Record 36 of Set 12 | makat
# Processing Record 37 of Set 12 | ostersund
# Processing Record 38 of Set 12 | muroto
# Processing Record 39 of Set 12 | sakaiminato
# Processing Record 40 of Set 12 | ocos
# Processing Record 41 of Set 12 | petauke
# Processing Record 42 of Set 12 | tautira
# Processing Record 43 of Set 12 | asau
# Processing Record 44 of Set 12 | santa cruz
# Processing Record 45 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 12 | krasnoselkup
# Processing Record 47 of Set 12 | nikel
# Processing Record 48 of Set 12 | manjacaze
# Processing Record 49 of Set 12 | ranong
# Processing Record 50 of Set 12 | estevan
# Processing Record 1 of Set 13 | shaoyang
# Processing Record 2 of Set 13 | salacgriva
# Processing Record 3 of Set 13 | gravdal
# Processing Record 4 of Set 13 | palana
# Processing Record 5 of Set 13 | prince rupert
# Processing Record 6 of Set 13 | akkermanovka
# Processing Record 7 of Set 13 | tarakan
# Processing Record 8 of Set 13 | san lawrenz
# Processing Record 9 of Set 13 | adrar
# Processing Record 10 of Set 13 | guatire
# Processing Record 11 of Set 13 | podor
# Processing Record 12 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 13 of Set 13 | thinadhoo
# Processing Record 14 of Set 13 | manono
# Processing Record 15 of Set 13 | shancheng
# Processing Record 16 of Set 13 | beringovskiy
# Processing Record 17 of Set 13 | moron
# Processing Record 18 of Set 13 | songjianghe
# Processing Record 19 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 13 | chikwawa
# Processing Record 21 of Set 13 | nuuk
# Processing Record 22 of Set 13 | south sioux city
# Processing Record 23 of Set 13 | aktash
# Processing Record 24 of Set 13 | piranhas
# Processing Record 25 of Set 13 | kingaroy
# Processing Record 26 of Set 13 | kargasok
# Processing Record 27 of Set 13 | touho
# Processing Record 28 of Set 13 | xilagani
# Processing Record 29 of Set 13 | skibbereen
# Processing Record 30 of Set 13 | sambava
# Processing Record 31 of Set 13 | lokoja
# Processing Record 32 of Set 13 | yumen
# Processing Record 33 of Set 13 | bar harbor
# Processing Record 34 of Set 13 | meulaboh
# Processing Record 35 of Set 13 | vanavara
# Processing Record 36 of Set 13 | sinop
# Processing Record 37 of Set 13 | viru
# Processing Record 38 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 39 of Set 13 | denpasar
# Processing Record 40 of Set 13 | carballo
# Processing Record 41 of Set 13 | portel
# Processing Record 42 of Set 13 | bhatkal
# Processing Record 43 of Set 13 | ust-kulom
# Processing Record 44 of Set 13 | lagoa
# Processing Record 45 of Set 13 | concarneau
# Processing Record 46 of Set 13 | fort nelson
# Processing Record 47 of Set 13 | lewistown
# Processing Record 48 of Set 13 | isla vista
# Processing Record 49 of Set 13 | ascoli piceno
# Processing Record 50 of Set 13 | mnogovershinnyy
# Processing Record 1 of Set 14 | altay
# Processing Record 2 of Set 14 | newcastle
# Processing Record 3 of Set 14 | fare
# Processing Record 4 of Set 14 | ivnya
# Processing Record 5 of Set 14 | qinhuangdao
# Processing Record 6 of Set 14 | kodinsk
# Processing Record 7 of Set 14 | wilmington
# Processing Record 8 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 14 | borger
# Processing Record 10 of Set 14 | gazanjyk
# Processing Record 11 of Set 14 | wheeling
# Processing Record 12 of Set 14 | hearst
# Processing Record 13 of Set 14 | makakilo city
# Processing Record 14 of Set 14 | sopotu nou
# Processing Record 15 of Set 14 | odweyne
# Processing Record 16 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 14 | nhulunbuy
# Processing Record 18 of Set 14 | talcahuano
# Processing Record 19 of Set 14 | zeya
# Processing Record 20 of Set 14 | dunedin
# Processing Record 21 of Set 14 | khash
# Processing Record 22 of Set 14 | elko
# Processing Record 23 of Set 14 | chenove
# Processing Record 24 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 14 | miri
# Processing Record 26 of Set 14 | kununurra
# Processing Record 27 of Set 14 | ahuimanu
# Processing Record 28 of Set 14 | dordrecht
# Processing Record 29 of Set 14 | chemax
# Processing Record 30 of Set 14 | tabou
# Processing Record 31 of Set 14 | ormond beach
# Processing Record 32 of Set 14 | graaff-reinet
# Processing Record 33 of Set 14 | san quintin
# Processing Record 34 of Set 14 | king city
# Processing Record 35 of Set 14 | la ronge
# Processing Record 36 of Set 14 | xuddur
# Processing Record 37 of Set 14 | okha
# Processing Record 38 of Set 14 | marabba
# Processing Record 39 of Set 14 | batouri
# Processing Record 40 of Set 14 | humaita
# Processing Record 41 of Set 14 | kupang
# Processing Record 42 of Set 14 | sumbe
# Processing Record 43 of Set 14 | camopi
# Processing Record 44 of Set 14 | abnub
# Processing Record 45 of Set 14 | moose factory
# Processing Record 46 of Set 14 | celestun
# Processing Record 47 of Set 14 | udachnyy
# Processing Record 48 of Set 14 | camana
# Processing Record 49 of Set 14 | rudbar
# Processing Record 50 of Set 14 | high level
# Processing Record 1 of Set 15 | roald
# Processing Record 2 of Set 15 | fuerte olimpo
# Processing Record 3 of Set 15 | alimanguan
# City not found. Skipping...
# Processing Record 4 of Set 15 | lazaro cardenas
# Processing Record 5 of Set 15 | husavik
# Processing Record 6 of Set 15 | narsingdi
# Processing Record 7 of Set 15 | teahupoo
# Processing Record 8 of Set 15 | paita
# Processing Record 9 of Set 15 | springdale
# Processing Record 10 of Set 15 | yulara
# Processing Record 11 of Set 15 | boa vista
# Processing Record 12 of Set 15 | ampanihy
# Processing Record 13 of Set 15 | tete
# Processing Record 14 of Set 15 | ananas
# Processing Record 15 of Set 15 | fengzhen
# Processing Record 16 of Set 15 | sooke
# Processing Record 17 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 18 of Set 15 | sandakan
# Processing Record 19 of Set 15 | kure
# Processing Record 20 of Set 15 | fez
# Processing Record 21 of Set 15 | kerema
# Processing Record 22 of Set 15 | buraydah
# Processing Record 23 of Set 15 | marsh harbour
# Processing Record 24 of Set 15 | takoradi
# Processing Record 25 of Set 15 | catamarca
# Processing Record 26 of Set 15 | anton lizardo
# Processing Record 27 of Set 15 | sinnamary
# Processing Record 28 of Set 15 | the valley
# Processing Record 29 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 15 | badou
# Processing Record 31 of Set 15 | yatou
# Processing Record 32 of Set 15 | hualmay
# Processing Record 33 of Set 15 | vigrestad
# Processing Record 34 of Set 15 | jerome
# Processing Record 35 of Set 15 | sesheke
# Processing Record 36 of Set 15 | vavuniya
# Processing Record 37 of Set 15 | sainte-anne-des-monts
# Processing Record 38 of Set 15 | simao
# Processing Record 39 of Set 15 | hambantota
# Processing Record 40 of Set 15 | green river
# Processing Record 41 of Set 15 | kamenka
# Processing Record 42 of Set 15 | mapimi
# Processing Record 43 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 15 | havre-saint-pierre
# Processing Record 45 of Set 15 | ust-uda
# Processing Record 46 of Set 15 | marseille
# Processing Record 47 of Set 15 | parbatipur
# Processing Record 48 of Set 15 | agadez
# Processing Record 49 of Set 15 | otradnoye
# Processing Record 50 of Set 15 | kyrksaeterora
# Processing Record 1 of Set 16 | bridlington
# Processing Record 2 of Set 16 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 16 | goderich
# Processing Record 4 of Set 16 | santa quiteria
# Processing Record 5 of Set 16 | marawi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert a list of dictionaries to a Pandas DataFrame 

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Awjilah  29.1081   21.2869     56.52        61           0        7.20
# 1      Ushuaia -54.8000  -68.3000     47.86        53          40       25.32
# 2       Hobart -42.8794  147.3294     67.26        55          75        4.00
# 3   Deniliquin -35.5333  144.9667     67.50        49          99       13.49
# 4      Rikitea -23.1203 -134.9692     76.69        73          87        6.26
# 5  Tuktoyaktuk  69.4541 -133.0374    -18.40        76           1        8.05
# 6      Huanren  41.2647  125.3667     33.76        94         100        2.71
# 7        Jumla  29.2747   82.1838     39.94        90          77        4.16
# 8      Emerald -23.5333  148.1667     80.74        69          40        9.22
# 9     Cidreira -30.1811  -50.2056     69.69        87          49       13.98
#
#   Country Current Description                 Date
# 0      LY           clear sky  2021-12-05 23:47:52
# 1      AR    scattered clouds  2021-12-05 23:47:53
# 2      AU       broken clouds  2021-12-05 23:45:48
# 3      AU     overcast clouds  2021-12-05 23:47:53
# 4      PF     overcast clouds  2021-12-05 23:47:54
# 5      CA           clear sky  2021-12-05 23:47:54
# 6      CN     overcast clouds  2021-12-05 23:47:55
# 7      NP       broken clouds  2021-12-05 23:47:56
# 8      AU    scattered clouds  2021-12-05 23:47:56
# 9      BR    scattered clouds  2021-12-05 23:47:57

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Awjilah      LY  29.1081   21.2869     56.52        61
# 1           Ushuaia      AR -54.8000  -68.3000     47.86        53
# 2            Hobart      AU -42.8794  147.3294     67.26        55
# 3        Deniliquin      AU -35.5333  144.9667     67.50        49
# 4           Rikitea      PF -23.1203 -134.9692     76.69        73
# ..              ...     ...      ...       ...       ...       ...
# 684   Kyrksaeterora      NO  63.2906    9.0891     29.05        86
# 685     Bridlington      GB  54.0831   -0.1919     39.15        67
# 686        Goderich      CA  43.7501  -81.7165     33.03        89
# 687  Santa Quiteria      BR  -4.3319  -40.1567     84.69        50
# 688          Marawi      PH   7.9986  124.2928     67.64        89
#
#      Cloudiness  Wind Speed Current Description
# 0             0        7.20           clear sky
# 1            40       25.32    scattered clouds
# 2            75        4.00       broken clouds
# 3            99       13.49     overcast clouds
# 4            87        6.26     overcast clouds
# ..          ...         ...                 ...
# 684          64        7.02       broken clouds
# 685          96        4.29     overcast clouds
# 686         100       30.09                snow
# 687          42        7.72    scattered clouds
# 688          99        3.29     overcast clouds
#
# [689 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
